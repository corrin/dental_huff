# %%
sample_percentage = 1.00  # % of the data
beta = 1.2  # Distance decay parameter
customer_value = 150  # Household dental spending per year

# %%
import pandas as pd
import pickle

# %%
import math

def ratings_to_size(rating):
    return (math.sqrt(rating) + 20) / 10

# %%
# Load the property coordinates from the Parquet file
property_data = pd.read_parquet('data/nz_property_lat_lon.parquet')
property_data = property_data.drop(columns=['WKT'])

# Load the deduplicated dentists
with open('data/deduplicated_dentists.pkl', 'rb') as f:
    deduplicated_dentists = pickle.load(f)

# Convert deduplicated_dentists to DataFrame for easier manipulation
dentists_df = pd.DataFrame(deduplicated_dentists)
dentists_df['size'] = dentists_df['reviews'].apply(ratings_to_size)

# Display a few rows to verify
display(property_data.head())
display(dentists_df.head())
# Out:
#     longitude   latitude
# 0  172.682428 -43.569101
# 1  174.766058 -36.850536
# 2  174.766289 -36.848008
# 3  174.770643 -36.847417
# 4  174.753391 -36.860142
#                       place_id                    name        lat         lon  \
# 0  ChIJn2iTgIGqEm0R3tcUFgH1VDY             Mint Dental -37.191588  174.903652
# 1  ChIJZ1N2dWKqEm0RZV_x3mljNxU  Pukekohe Orthodontists -37.074346  174.922603
# 2  ChIJPx17MdWscm0RaYxnKNKfAcg   Vanessa Wright Dental -37.062908  174.940487
# 3  ChIJiQWVRdSscm0RgB5b7NnhmNM         The Denture Man -37.064653  174.943538
# 4  ChIJz13Dp9Wscm0Ru9TUvS4DslY   Dental World Papakura -37.063301  174.943527
#
#    reviews      size
# 0       39  2.624500
# 1        3  2.173205
# 2       11  2.331662
# 3        9  2.300000
# 4        7  2.264575

# %%
sample_size = int(len(property_data) * sample_percentage)  # Sample % of the rows

# Define property_for_huff which can be set to either the full data or a sample
def set_property_for_huff(full_data, sample_size=None):
    if sample_size:
        return full_data.sample(n=sample_size, random_state=42)  # Create a random sample
    return full_data  # Use the full dataset if no sample_size is provided

# Example usage
# For full data (use this in the main run)
property_for_huff = set_property_for_huff(property_data, sample_size)

# For testing with a random sample of, say, 1000 rows (use this for faster testing)
# property_for_huff = set_property_for_huff(property_data, sample_size=1000)

# Display the first few rows to verify
display(property_for_huff.head())
# Out:
#           longitude   latitude
# 1440305  173.937789 -41.507538
# 1921502  174.362696 -35.751926
# 2140332  175.009620 -37.237635
# 246221   172.598556 -43.497314
# 1196567  175.629666 -40.346956

# %%
import numpy as np

# Function to calculate distance between two points (Haversine formula)
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371  # Radius of Earth in kilometers
    return c * r  # Distance in kilometers

# Test the function

# %%
from tqdm import tqdm


# Convert property data and dentists data to NumPy arrays for fast operations
property_lats = property_for_huff['latitude'].values
property_lons = property_for_huff['longitude'].values

dentist_lats = dentists_df['lat'].values
dentist_lons = dentists_df['lon'].values
dentist_sizes = dentists_df['size'].values

# Initialize an array to store the total estimated revenue for each dentist
revenue_per_practice = np.zeros(len(dentist_lats))

# Vectorized calculation of distances from all properties to all dentists
for i in tqdm(range(len(property_lats)), desc="Processing Properties", total=len(property_lats)):
    # Compute distances from the current property to all dentists at once
    distances = haversine(property_lats[i], property_lons[i], dentist_lats, dentist_lons)

    # Compute size over distance^beta (for all dentists)
    size_over_distance = dentist_sizes / distances**beta
    
    # Compute the probabilities (for all dentists)
    probabilities = size_over_distance / size_over_distance.sum()

    # Distribute customer value to each dental practice based on the probabilities
    revenue_per_practice += probabilities * customer_value
# Out:
# Processing Properties: 100%|██████████| 2360762/2360762 [01:17<00:00, 30400.84it/s]

# %%
property_lats.shape
# Out:
# (2360762,)

# %%
# Scale the revenue by the sampling ratio (to account for partial data)
revenue_per_practice /= sample_percentage

# Add the revenue estimate to the dentists DataFrame
dentists_df['estimated_revenue'] = revenue_per_practice

# %%
from IPython.display import display
pd.set_option('display.max_rows', None)

# Sort the DataFrame by 'estimated_revenue' first (while it's still numeric)
sorted_dentists_df = dentists_df.sort_values(by='estimated_revenue', ascending=False)

# Truncate the name at 30 characters and create a new column for the formatted revenue
sorted_dentists_df['name_truncated'] = sorted_dentists_df['name'].apply(lambda x: x[:30])
sorted_dentists_df['formatted_revenue'] = sorted_dentists_df['estimated_revenue'].map(lambda x: f"${x:,.0f}")

# Select relevant columns for display
formatted_output = sorted_dentists_df[['name_truncated', 'formatted_revenue']]

# Display the formatted DataFrame
display(formatted_output)
# Out:
#                      name_truncated formatted_revenue
# 161  Smile Dental - Queen Street -         $6,317,472
# 35         Maxcare Dental - Otahuhu        $5,515,948
# 72           Donna Lim Orthodontics        $4,891,479
# 69   Stoddard Dental Square ! Emerg        $4,591,011
# 134     Pt Chevalier Family Dentist        $4,504,785
# 12           Smile Dental - Manukau        $4,466,323
# 142  Dental Artistry - Auckland Den        $4,408,717
# 154  Accent Dentists - Cosmetic Den        $4,386,621
# 183                 Northmed Dental        $4,377,887
# 45     Blockhouse Bay Dental Centre        $4,351,342
# 107                   Alpers Dental        $4,311,133
# 41                  DentalCare West        $4,172,019
# 156  The Fono City Healthcare Centr        $4,111,866
# 173             Affordable Dentists        $4,107,702
# 129                  CM Dental Ltd.        $4,064,981
# 55   Smile Dental - Onehunga Dentis        $4,047,840
# 139                  Grafton Dental        $4,024,030
# 199  Auckland Family Dental: Milfor        $3,990,996
# 140    Symonds Street Dental Centre        $3,989,407
# 49   Quality Care Dental | Dentist         $3,964,454
# 137               Eden Orthodontics        $3,947,283
# 187  Shakespeare Orthodontics Takap        $3,932,439
# 109  Shakespeare Orthodontics Epsom        $3,909,356
# 164  Lumino City Dental at Quay Par        $3,905,576
# 149                    Hello Dental        $3,889,971
# 78     Caring 4 Smiles Dental Group        $3,851,072
# 47            Auckland Orthodontics        $3,842,656
# 44           West Auckland Dentists        $3,779,478
# 52            Dental Today Onehunga        $3,754,694
# 217           Bayside Dental Centre        $3,749,695
# 87   Primecare Dental Highland Park        $3,723,667
# 5                  Nova Dental Care        $3,704,036
# 200               Sunnynook Dentist        $3,702,308
# 101               All Smiles Dental        $3,694,665
# 57           Ti Rakau Dental Centre        $3,682,968
# 106                  Epsom Dentists        $3,649,966
# 130              White Cross Dental        $3,641,842
# 195  Mint Dental Hygiene / Nova Edg        $3,640,270
# 150                Dr Dave Richards        $3,627,998
# 13             Guardian Dental Care        $3,623,556
# 6             Clendon Dental Centre        $3,570,240
# 9            Mahu Dental - Manurewa        $3,570,010
# 65   Auckland Family Dental: New Ly        $3,547,082
# 64      White Cross Dental New Lynn        $3,545,561
# 63              Kelston Dental Care        $3,540,734
# 80            Penrose Dental Clinic        $3,536,924
# 148     The Tooth Company Eastridge        $3,522,493
# 127   Marina Dentists Half Moon Bay        $3,506,768
# 166     The Tooth Company Britomart        $3,502,175
# 97        Mount Albert Orthodontics        $3,493,895
# 159                Re Dental Clinic        $3,483,759
# 0                       Mint Dental        $3,476,279
# 14             Southern Care Dental        $3,474,066
# 205                     Bays Dental        $3,450,491
# 70           Dominion Dental Centre        $3,449,610
# 220              Clean Teeth Dental        $3,448,306
# 105               Neo Dental Studio        $3,443,262
# 94   The Fono Henderson Healthcare         $3,433,448
# 33   Primecare Dental Mangere Bridg        $3,425,321
# 162  Auckland Central | Lumino The         $3,417,581
# 60         Family Dentist Pakuranga        $3,415,942
# 10   The Fono Manurewa Healthcare C        $3,403,629
# 102  Lumino The Dentists Mount Eden        $3,401,761
# 174       Mokoia Road Dental Centre        $3,399,466
# 90                      A+ Dentists        $3,396,576
# 37            Mahu Dental - Otahuhu        $3,396,431
# 82    Affordable Dentists Ellerslie        $3,392,204
# 138  Ponsonby Dentist | Lumino The         $3,390,588
# 128                Macleans Dentist        $3,390,217
# 204                The Tooth Doctor        $3,384,596
# 179        Hobsonville Point Dental        $3,379,918
# 196            Auckland Dental Care        $3,379,784
# 7                     Loudon Dental        $3,355,611
# 176         Northcote Dental Centre        $3,345,008
# 56           My Dentist - Pakuranga        $3,337,119
# 180               Ocean View Dental        $3,336,702
# 144               Milk Orthodontics        $3,329,641
# 43   Lumino The Dentists | New Lynn        $3,325,862
# 212                 Greville Dental        $3,301,409
# 11   Advanced Dental Care Manurewa         $3,297,275
# 81                 Greenlane Dental        $3,293,986
# 24        Papatoetoe Family Dentist        $3,287,713
# 62                 Golflands Dental        $3,284,807
# 145          Janice Sommerville Ltd        $3,283,366
# 178                   Fraser Dental        $3,270,506
# 104  Lumino Mount Eden Village | Lu        $3,269,485
# 100            Flash Dental Mt Eden        $3,258,812
# 112                 Cosmetic Dental        $3,256,972
# 67             Totara Orthodontists        $3,249,912
# 219  Dr Kimberley Timmins Specialis        $3,249,103
# 157        Ponsonby Dental Boutique        $3,248,327
# 22                  Guardian Dental        $3,237,946
# 18             Prisca Dental Centre        $3,225,576
# 53          Trafalgar Family Dental        $3,217,911
# 66                   Quality Dental        $3,217,907
# 208                   JJ Dentalcare        $3,215,202
# 29              Botany South Dental        $3,215,040
# 211                 Northmed Dental        $3,213,000
# 84             Dental World Panmure        $3,209,818
# 184   The Tooth Company Smales Farm        $3,207,985
# 170                   Massey Smiles        $3,206,531
# 8            Manurewa Dental Centre        $3,185,570
# 110                 Dental Cosmetic        $3,180,481
# 158                  Ponsonby Teeth        $3,173,805
# 28              East Tamaki Dentist        $3,171,313
# 36            South Auckland Dental        $3,165,735
# 71                  Thompson Dental        $3,164,498
# 201                     Star Dental        $3,153,459
# 120                 Lunn Dental Spa        $3,151,036
# 34              OTAHUHU DENTAL CARE        $3,150,618
# 182              The Dental Experts        $3,125,022
# 98      White Cross Dental St Lukes        $3,118,373
# 32          Titirangi Dental Centre        $3,097,519
# 165                 Downtown Dental        $3,096,681
# 96           Dental on Mount Albert        $3,094,435
# 27                 Flat Bush Dental        $3,087,924
# 76           Balmoral Dental Centre        $3,080,856
# 209               DBS Dental Studio        $3,079,246
# 23         Papatoetoe Dental Centre        $3,074,458
# 153  Ponsonby Accident & Emergency         $3,072,315
# 123             Urban Dental Studio        $3,064,958
# 206              Sunset Dental Care        $3,060,194
# 155      Freemans Bay Dental Centre        $3,055,235
# 215           Albany Village Dental        $3,054,372
# 79   Gentle Dentists Ellerslie | Lu        $3,053,846
# 118  Max + Beresford Orthodontists         $3,048,647
# 191  Takapuna Como Street | Lumino         $3,040,777
# 74   Lumino Three Kings | Lumino Th        $3,035,308
# 198                Milford Dentists        $3,033,991
# 135      Pt Chevalier Dental Centre        $3,030,838
# 136              Eden Dental Centre        $3,026,168
# 175          Dentists on Birkenhead        $3,022,797
# 172  Viva Dental Birkenhead | Lumin        $3,006,232
# 146               Aevitas Dentistry        $3,005,409
# 203  Wairau Park Dental Centre | Lu        $3,001,260
# 171                Devonport Dental        $2,990,776
# 2             Vanessa Wright Dental        $2,981,461
# 16       Airport Oaks Dental Centre        $2,976,519
# 17            Mangere Dental Centre        $2,974,625
# 188               Takapuna Dentists        $2,973,686
# 26   Ormiston Dental Centre Flat Bu        $2,972,863
# 143                  Inspire Dental        $2,963,714
# 131  Henderson Dental Practice | Lu        $2,962,790
# 168            Massey Dental Centre        $2,957,044
# 73        Three Kings Dental Centre        $2,955,917
# 3                   The Denture Man        $2,951,615
# 126        Glen Innes Dental Centre        $2,945,708
# 25   Botany Orthodontist - Coreen L        $2,942,605
# 51           Onehunga Dental Centre        $2,923,975
# 152                 Dental Boutique        $2,921,872
# 121  Kidz-Teeth Meadowbank | Lumino        $2,919,117
# 193      Takapuna Orthodontic Group        $2,915,347
# 113  Lumino The Dentists: Remuera D        $2,913,452
# 77          Auckland Denture Clinic        $2,905,987
# 4             Dental World Papakura        $2,899,727
# 39   Botany Dental Practice | Lumin        $2,898,421
# 19           Papatoetoe Dental Care        $2,895,721
# 61              The Dental Practice        $2,893,457
# 124          Dental Wellness Centre        $2,873,085
# 88          The Endodontic Practice        $2,872,862
# 21        John Hodgson Orthodontist        $2,869,547
# 163           Auckland City Dentist        $2,853,833
# 42   Frank Matheson's Dental Surger        $2,851,712
# 108                   Belich Dental        $2,848,913
# 181  Glenfield Dental North Shore |        $2,848,438
# 114   Catherine Porter Orthodontist        $2,825,897
# 132           Peninsula Dental Care        $2,819,470
# 122        Meadowbank Dental Centre        $2,812,784
# 125              Glen Innes Dentist        $2,812,535
# 91             Dental Planet Howick        $2,800,230
# 89      Highland Park Dental Centre        $2,795,714
# 115  Pearl Dental Centre Remuera |         $2,787,818
# 218    The Dental Centre Browns Bay        $2,785,772
# 169          Westgate Dental Centre        $2,785,183
# 31    Titirangi Village Dental Care        $2,783,523
# 20            Hunters Corner Dental        $2,779,430
# 167  Lumino St Heliers | Lumino The        $2,774,438
# 50          The Dentists - Auckland        $2,766,359
# 30                 VS Dental Studio        $2,753,052
# 202            Kim's Dental Surgery        $2,750,268
# 116             Dental On Greenlane        $2,734,264
# 54                Onehunga Dentists        $2,726,467
# 95                  Te Atatu Dental        $2,719,391
# 59             Dentalcare Pakuranga        $2,713,822
# 68         HillPark Dental Avondale        $2,713,306
# 85   Fraser Smith Lowe Dentists Lim        $2,708,183
# 75        Sandringham Dental Centre        $2,696,089
# 151         St Heliers Dental Group        $2,692,087
# 103  Balmoral Intermediate Children        $2,689,564
# 83            Panmure Dental Centre        $2,686,097
# 117                          .Ortho        $2,679,679
# 141       Casley, Wong & Tam Dental        $2,673,827
# 160                   Dental Direct        $2,668,927
# 133                    Meola Dental        $2,667,803
# 177               Dental Studio 114        $2,659,750
# 210  Lumino Rosedale | Lumino The D        $2,658,906
# 207                     Tusk Dental        $2,649,089
# 186              My Dental Implants        $2,648,425
# 1            Pukekohe Orthodontists        $2,647,320
# 48     Mt Roskill South Dental Care        $2,616,784
# 192                  JJY Dental Ltd        $2,603,543
# 92    Derek Barwood Orthodontic Ltd        $2,575,002
# 99                   Dental Surgeon        $2,572,947
# 58         Pakuranga Dental Surgery        $2,563,332
# 147                  Chris Waalkens        $2,562,834
# 197            Huapai Dental Centre        $2,538,071
# 216  Northcross Intermediate dental        $2,533,402
# 86   Wakaaranga School Dental Clini        $2,531,584
# 213           Albany Dental Surgery        $2,489,165
# 93   Shakespeare Orthodontics Howic        $2,476,708
# 15            Manukau Dental Clinic        $2,450,492
# 40                      Dr Jacy Lin        $2,394,696
# 111                       Smileplan        $2,360,755
# 119  Auckland City Orthodontics Rem        $2,348,754
# 46                   Dr John Coburn        $2,341,545
# 38   Auckland City Orthodontics Hig        $2,328,608
# 194        North Shore Periodontics        $2,320,506
# 190  Bunyan Dr TR Specialist Orthod        $2,306,592
# 185                Warren Jenks Ltd        $2,303,854
# 189                         goSmart        $2,195,964
# 214            White Crystal Dental        $2,162,671

# %%
dentists_df.head()
# Out:
#                       place_id                    name        lat         lon  \
# 0  ChIJn2iTgIGqEm0R3tcUFgH1VDY             Mint Dental -37.191588  174.903652
# 1  ChIJZ1N2dWKqEm0RZV_x3mljNxU  Pukekohe Orthodontists -37.074346  174.922603
# 2  ChIJPx17MdWscm0RaYxnKNKfAcg   Vanessa Wright Dental -37.062908  174.940487
# 3  ChIJiQWVRdSscm0RgB5b7NnhmNM         The Denture Man -37.064653  174.943538
# 4  ChIJz13Dp9Wscm0Ru9TUvS4DslY   Dental World Papakura -37.063301  174.943527
#
#    reviews      size  estimated_revenue
# 0       39  2.624500       3.476279e+06
# 1        3  2.173205       2.647320e+06
# 2       11  2.331662       2.981461e+06
# 3        9  2.300000       2.951615e+06
# 4        7  2.264575       2.899727e+06

# %%
property_data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 property_data.shape
#
# NameError: name 'property_data' is not defined

# %%
sorted_dentists_df.head()
