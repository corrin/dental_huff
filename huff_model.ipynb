# %%
sample_percentage = 1.00  # % of the data
beta = 1.1  # Distance decay parameter
customer_value = 300  # Household dental spending per year

# %%
import pandas as pd
import pickle

# %%
import math

def ratings_to_size(rating):
    return (math.sqrt(rating) + 20) / 10

# %%
# Load the property coordinates from the Parquet file
property_data = pd.read_parquet('data/nz_property_lat_lon.parquet')
property_data = property_data.drop(columns=['WKT'])

# Load the deduplicated dentists
with open('data/deduplicated_dentists.pkl', 'rb') as f:
    deduplicated_dentists = pickle.load(f)

# Convert deduplicated_dentists to DataFrame for easier manipulation
dentists_df = pd.DataFrame(deduplicated_dentists)
dentists_df['size'] = dentists_df['reviews'].apply(ratings_to_size)

# Display a few rows to verify
display(property_data.head())
display(dentists_df.head())
# Out:
#                                           WKT   longitude   latitude
# 0  POINT (172.682427990989 -43.5691006197534)  172.682428 -43.569101
# 1   POINT (174.76605808985 -36.8505358230548)  174.766058 -36.850536
# 2  POINT (174.766289274903 -36.8480077210557)  174.766289 -36.848008
# 3   POINT (174.77064284915 -36.8474174525228)  174.770643 -36.847417
# 4  POINT (174.753390890909 -36.8601424547084)  174.753391 -36.860142
#                       place_id                    name        lat         lon  \
# 0  ChIJn2iTgIGqEm0R3tcUFgH1VDY             Mint Dental -37.191588  174.903652
# 1  ChIJZ1N2dWKqEm0RZV_x3mljNxU  Pukekohe Orthodontists -37.074346  174.922603
# 2  ChIJPx17MdWscm0RaYxnKNKfAcg   Vanessa Wright Dental -37.062908  174.940487
# 3  ChIJiQWVRdSscm0RgB5b7NnhmNM         The Denture Man -37.064653  174.943538
# 4  ChIJz13Dp9Wscm0Ru9TUvS4DslY   Dental World Papakura -37.063301  174.943527
#
#    reviews
# 0       39
# 1        3
# 2       11
# 3        9
# 4        7

# %%
sample_size = int(len(property_data) * sample_percentage)  # Sample 10% of the rows

# Define property_for_huff which can be set to either the full data or a sample
def set_property_for_huff(full_data, sample_size=None):
    if sample_size:
        return full_data.sample(n=sample_size, random_state=42)  # Create a random sample
    return full_data  # Use the full dataset if no sample_size is provided

# Example usage
# For full data (use this in the main run)
property_for_huff = set_property_for_huff(property_data,sample_size=100000)

# For testing with a random sample of, say, 1000 rows (use this for faster testing)
# property_for_huff = set_property_for_huff(property_data, sample_size=1000)

# Display the first few rows to verify
print(property_for_huff.head())
# Out:
#                                            WKT   longitude   latitude
# 1440305     POINT (173.9377888167 -41.5075379)  173.937789 -41.507538
# 1921502  POINT (174.3626960667 -35.7519257167)  174.362696 -35.751926
# 2140332  POINT (175.0096198333 -37.2376353167)  175.009620 -37.237635
# 246221      POINT (172.5985556167 -43.4973139)  172.598556 -43.497314
# 1196567  POINT (175.6296664333 -40.3469563333)  175.629666 -40.346956

# %%
from math import sqrt

# Ensure 'reviews' column exists and calculate the size (proxy) as sqrt of reviews
dentists_df['size'] = dentists_df['reviews'].apply(lambda x: sqrt(x)) + 20

# Display to check
print(dentists_df[['name', 'reviews', 'size']].head())
# Out:
#                      name  reviews       size
# 0             Mint Dental       39  26.244998
# 1  Pukekohe Orthodontists        3  21.732051
# 2   Vanessa Wright Dental       11  23.316625
# 3         The Denture Man        9  23.000000
# 4   Dental World Papakura        7  22.645751

# %%
import numpy as np

# Function to calculate distance between two points (Haversine formula)
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371  # Radius of Earth in kilometers
    return c * r  # Distance in kilometers

# Test the function
print(haversine(-36.8485, 174.7633, -36.8484, 174.7634))  # Test distance in Auckland
# Out:
# 0.014241458474257587

# %%
from tqdm import tqdm


# Convert property data and dentists data to NumPy arrays for fast operations
property_lats = property_for_huff['latitude'].values
property_lons = property_for_huff['longitude'].values

dentist_lats = dentists_df['lat'].values
dentist_lons = dentists_df['lon'].values
dentist_sizes = dentists_df['size'].values

# Initialize an array to store the total estimated revenue for each dentist
revenue_per_practice = np.zeros(len(dentist_lats))

# Vectorized calculation of distances from all properties to all dentists
for i in tqdm(range(len(property_lats)), desc="Processing Properties", total=len(property_lats)):
    # Compute distances from the current property to all dentists at once
    distances = haversine(property_lats[i], property_lons[i], dentist_lats, dentist_lons)

    # Compute size over distance^beta (for all dentists)
    size_over_distance = dentist_sizes / distances**beta
    
    # Compute the probabilities (for all dentists)
    probabilities = size_over_distance / size_over_distance.sum()

    # Distribute customer value to each dental practice based on the probabilities
    revenue_per_practice += probabilities * customer_value

# %%
# Scale the revenue by the sampling ratio (to account for partial data)
revenue_per_practice /= sample_percentage

# Add the revenue estimate to the dentists DataFrame
dentists_df['estimated_revenue'] = revenue_per_practice

# %%
from IPython.display import display
pd.set_option('display.max_rows', None)

# Sort the DataFrame by 'estimated_revenue' first (while it's still numeric)
sorted_dentists_df = dentists_df.sort_values(by='estimated_revenue', ascending=False)

# Truncate the name at 30 characters and create a new column for the formatted revenue
sorted_dentists_df['name_truncated'] = sorted_dentists_df['name'].apply(lambda x: x[:30])
sorted_dentists_df['formatted_revenue'] = sorted_dentists_df['estimated_revenue'].map(lambda x: f"${x:,.0f}")

# Select relevant columns for display
formatted_output = sorted_dentists_df[['name_truncated', 'formatted_revenue']]

# Display the formatted DataFrame
display(formatted_output)
# Out:
#                      name_truncated formatted_revenue
# 161  Smile Dental - Queen Street -           $325,189
# 35         Maxcare Dental - Otahuhu          $286,087
# 72           Donna Lim Orthodontics          $235,568
# 12           Smile Dental - Manukau          $228,518
# 0                       Mint Dental          $225,835
# 69   Stoddard Dental Square ! Emerg          $218,777
# 134     Pt Chevalier Family Dentist          $214,568
# 41                  DentalCare West          $211,217
# 45     Blockhouse Bay Dental Centre          $208,300
# 129                  CM Dental Ltd.          $207,944
# 183                 Northmed Dental          $203,412
# 142  Dental Artistry - Auckland Den          $199,094
# 5                  Nova Dental Care          $198,179
# 154  Accent Dentists - Cosmetic Den          $196,230
# 140    Symonds Street Dental Centre          $194,760
# 6             Clendon Dental Centre          $194,041
# 107                   Alpers Dental          $188,600
# 55   Smile Dental - Onehunga Dentis          $188,107
# 199  Auckland Family Dental: Milfor          $187,376
# 173             Affordable Dentists          $186,853
# 217           Bayside Dental Centre          $184,728
# 156  The Fono City Healthcare Centr          $184,176
# 49   Quality Care Dental | Dentist           $182,921
# 139                  Grafton Dental          $182,856
# 149                    Hello Dental          $182,418
# 164  Lumino City Dental at Quay Par          $178,958
# 187  Shakespeare Orthodontics Takap          $175,469
# 130              White Cross Dental          $174,721
# 47            Auckland Orthodontics          $174,181
# 9            Mahu Dental - Manurewa          $173,385
# 137               Eden Orthodontics          $172,984
# 44           West Auckland Dentists          $171,630
# 78     Caring 4 Smiles Dental Group          $169,834
# 200               Sunnynook Dentist          $169,328
# 57           Ti Rakau Dental Centre          $169,092
# 87   Primecare Dental Highland Park          $168,863
# 150                Dr Dave Richards          $168,643
# 94   The Fono Henderson Healthcare           $167,977
# 13             Guardian Dental Care          $167,786
# 52            Dental Today Onehunga          $166,514
# 63              Kelston Dental Care          $166,189
# 109  Shakespeare Orthodontics Epsom          $165,393
# 179        Hobsonville Point Dental          $164,641
# 10   The Fono Manurewa Healthcare C          $160,948
# 14             Southern Care Dental          $157,293
# 90                      A+ Dentists          $157,258
# 7                     Loudon Dental          $157,243
# 220              Clean Teeth Dental          $156,894
# 64      White Cross Dental New Lynn          $156,767
# 148     The Tooth Company Eastridge          $156,296
# 195  Mint Dental Hygiene / Nova Edg          $155,858
# 205                     Bays Dental          $155,391
# 101               All Smiles Dental          $155,304
# 65   Auckland Family Dental: New Ly          $155,103
# 127   Marina Dentists Half Moon Bay          $154,940
# 128                Macleans Dentist          $153,641
# 106                  Epsom Dentists          $153,573
# 178                   Fraser Dental          $153,492
# 212                 Greville Dental          $153,064
# 33   Primecare Dental Mangere Bridg          $152,583
# 11   Advanced Dental Care Manurewa           $152,284
# 80            Penrose Dental Clinic          $151,183
# 170                   Massey Smiles          $149,741
# 60         Family Dentist Pakuranga          $148,400
# 174       Mokoia Road Dental Centre          $148,372
# 97        Mount Albert Orthodontics          $148,203
# 204                The Tooth Doctor          $148,102
# 82    Affordable Dentists Ellerslie          $147,161
# 166     The Tooth Company Britomart          $146,556
# 37            Mahu Dental - Otahuhu          $146,046
# 18             Prisca Dental Centre          $145,861
# 56           My Dentist - Pakuranga          $145,504
# 70           Dominion Dental Centre          $144,841
# 62                 Golflands Dental          $144,409
# 8            Manurewa Dental Centre          $143,913
# 219  Dr Kimberley Timmins Specialis          $143,685
# 138  Ponsonby Dentist | Lumino The           $142,530
# 180               Ocean View Dental          $142,413
# 159                Re Dental Clinic          $141,299
# 24        Papatoetoe Family Dentist          $140,742
# 208                   JJ Dentalcare          $140,662
# 105               Neo Dental Studio          $140,530
# 196            Auckland Dental Care          $140,319
# 43   Lumino The Dentists | New Lynn          $140,275
# 27                 Flat Bush Dental          $140,103
# 176         Northcote Dental Centre          $139,747
# 211                 Northmed Dental          $139,643
# 2             Vanessa Wright Dental          $139,169
# 3                   The Denture Man          $138,705
# 28              East Tamaki Dentist          $138,321
# 84             Dental World Panmure          $137,595
# 32          Titirangi Dental Centre          $137,121
# 102  Lumino The Dentists Mount Eden          $136,990
# 29              Botany South Dental          $136,712
# 22                  Guardian Dental          $136,691
# 120                 Lunn Dental Spa          $136,258
# 162  Auckland Central | Lumino The           $135,267
# 53          Trafalgar Family Dental          $135,126
# 168            Massey Dental Centre          $134,776
# 67             Totara Orthodontists          $134,435
# 17            Mangere Dental Centre          $134,359
# 209               DBS Dental Studio          $133,817
# 201                     Star Dental          $133,316
# 4             Dental World Papakura          $133,051
# 66                   Quality Dental          $132,977
# 104  Lumino Mount Eden Village | Lu          $132,888
# 81                 Greenlane Dental          $132,684
# 36            South Auckland Dental          $132,594
# 215           Albany Village Dental          $131,652
# 184   The Tooth Company Smales Farm          $130,935
# 144               Milk Orthodontics          $130,919
# 34              OTAHUHU DENTAL CARE          $130,712
# 123             Urban Dental Studio          $130,166
# 131  Henderson Dental Practice | Lu          $129,785
# 100            Flash Dental Mt Eden          $129,564
# 98      White Cross Dental St Lukes          $129,554
# 206              Sunset Dental Care          $129,128
# 157        Ponsonby Dental Boutique          $128,273
# 145          Janice Sommerville Ltd          $127,853
# 23         Papatoetoe Dental Centre          $127,454
# 71                  Thompson Dental          $126,306
# 112                 Cosmetic Dental          $126,123
# 198                Milford Dentists          $126,050
# 16       Airport Oaks Dental Centre          $125,601
# 182              The Dental Experts          $124,600
# 181  Glenfield Dental North Shore |          $124,527
# 175          Dentists on Birkenhead          $123,786
# 76           Balmoral Dental Centre          $123,165
# 96           Dental on Mount Albert          $123,054
# 158                  Ponsonby Teeth          $122,619
# 203  Wairau Park Dental Centre | Lu          $122,550
# 169          Westgate Dental Centre          $121,937
# 171                Devonport Dental          $121,776
# 61              The Dental Practice          $121,499
# 26   Ormiston Dental Centre Flat Bu          $121,456
# 74   Lumino Three Kings | Lumino Th          $121,277
# 135      Pt Chevalier Dental Centre          $120,942
# 110                 Dental Cosmetic          $120,806
# 126        Glen Innes Dental Centre          $120,224
# 191  Takapuna Como Street | Lumino           $120,124
# 172  Viva Dental Birkenhead | Lumin          $119,938
# 25   Botany Orthodontist - Coreen L          $119,357
# 95                  Te Atatu Dental          $118,492
# 42   Frank Matheson's Dental Surger          $118,173
# 1            Pukekohe Orthodontists          $118,137
# 79   Gentle Dentists Ellerslie | Lu          $118,046
# 132           Peninsula Dental Care          $117,466
# 218    The Dental Centre Browns Bay          $117,396
# 136              Eden Dental Centre          $117,394
# 77          Auckland Denture Clinic          $116,784
# 153  Ponsonby Accident & Emergency           $116,754
# 197            Huapai Dental Centre          $116,505
# 39   Botany Dental Practice | Lumin          $116,172
# 73        Three Kings Dental Centre          $116,156
# 19           Papatoetoe Dental Care          $115,866
# 165                 Downtown Dental          $115,618
# 188               Takapuna Dentists          $115,567
# 30                 VS Dental Studio          $115,309
# 31    Titirangi Village Dental Care          $114,966
# 155      Freemans Bay Dental Centre          $114,711
# 91             Dental Planet Howick          $114,035
# 88          The Endodontic Practice          $113,383
# 21        John Hodgson Orthodontist          $113,310
# 121  Kidz-Teeth Meadowbank | Lumino          $113,237
# 118  Max + Beresford Orthodontists           $113,133
# 51           Onehunga Dental Centre          $112,323
# 146               Aevitas Dentistry          $111,817
# 193      Takapuna Orthodontic Group          $111,563
# 167  Lumino St Heliers | Lumino The          $111,192
# 89      Highland Park Dental Centre          $111,164
# 125              Glen Innes Dentist          $110,503
# 124          Dental Wellness Centre          $110,320
# 113  Lumino The Dentists: Remuera D          $109,800
# 143                  Inspire Dental          $109,532
# 152                 Dental Boutique          $109,444
# 122        Meadowbank Dental Centre          $108,322
# 216  Northcross Intermediate dental          $107,569
# 202            Kim's Dental Surgery          $107,228
# 50          The Dentists - Auckland          $105,932
# 151         St Heliers Dental Group          $105,919
# 68         HillPark Dental Avondale          $105,629
# 20            Hunters Corner Dental          $105,480
# 114   Catherine Porter Orthodontist          $104,459
# 83            Panmure Dental Centre          $104,190
# 85   Fraser Smith Lowe Dentists Lim          $102,343
# 210  Lumino Rosedale | Lumino The D          $102,182
# 163           Auckland City Dentist          $102,090
# 207                     Tusk Dental          $101,896
# 59             Dentalcare Pakuranga          $101,275
# 108                   Belich Dental          $100,878
# 133                    Meola Dental          $100,601
# 54                Onehunga Dentists          $100,592
# 92    Derek Barwood Orthodontic Ltd           $98,740
# 115  Pearl Dental Centre Remuera |            $98,050
# 75        Sandringham Dental Centre           $97,753
# 177               Dental Studio 114           $97,745
# 116             Dental On Greenlane           $97,429
# 48     Mt Roskill South Dental Care           $97,343
# 117                          .Ortho           $96,829
# 186              My Dental Implants           $95,243
# 103  Balmoral Intermediate Children           $94,923
# 160                   Dental Direct           $94,921
# 213           Albany Dental Surgery           $94,157
# 192                  JJY Dental Ltd           $92,274
# 86   Wakaaranga School Dental Clini           $91,879
# 93   Shakespeare Orthodontics Howic           $91,245
# 58         Pakuranga Dental Surgery           $91,141
# 141       Casley, Wong & Tam Dental           $90,662
# 99                   Dental Surgeon           $90,016
# 15            Manukau Dental Clinic           $86,152
# 40                      Dr Jacy Lin           $84,494
# 147                  Chris Waalkens           $83,862
# 185                Warren Jenks Ltd           $80,790
# 46                   Dr John Coburn           $79,475
# 38   Auckland City Orthodontics Hig           $75,813
# 194        North Shore Periodontics           $74,730
# 190  Bunyan Dr TR Specialist Orthod           $74,566
# 214            White Crystal Dental           $72,884
# 111                       Smileplan           $71,740
# 119  Auckland City Orthodontics Rem           $70,976
# 189                         goSmart           $67,240

# %%
dentists_df.head()
# Out:
#                       place_id                    name        lat         lon  \
# 0  ChIJn2iTgIGqEm0R3tcUFgH1VDY             Mint Dental -37.191588  174.903652
# 1  ChIJZ1N2dWKqEm0RZV_x3mljNxU  Pukekohe Orthodontists -37.074346  174.922603
# 2  ChIJPx17MdWscm0RaYxnKNKfAcg   Vanessa Wright Dental -37.062908  174.940487
# 3  ChIJiQWVRdSscm0RgB5b7NnhmNM         The Denture Man -37.064653  174.943538
# 4  ChIJz13Dp9Wscm0Ru9TUvS4DslY   Dental World Papakura -37.063301  174.943527
#
#    reviews       size  estimated_revenue
# 0       39  16.244998       2.258345e+06
# 1        3  11.732051       1.181371e+06
# 2       11  13.316625       1.391686e+06
# 3        9  13.000000       1.387053e+06
# 4        7  12.645751       1.330511e+06
