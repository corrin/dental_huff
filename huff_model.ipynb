# %%
sample_percentage = 1.00  # % of the data
beta = 1.2  # Distance decay parameter
customer_value = 150  # Household dental spending per year

# %%
import pandas as pd
import pickle

# %%
import math

def ratings_to_size(rating):
    return (math.sqrt(rating) + 20) / 10

# %%
# Load the property coordinates from the Parquet file
property_data = pd.read_parquet('data/nz_property_lat_lon.parquet')
property_data = property_data.drop(columns=['WKT'])

# Load the deduplicated dentists
with open('data/deduplicated_dentists.pkl', 'rb') as f:
    deduplicated_dentists = pickle.load(f)

# Convert deduplicated_dentists to DataFrame for easier manipulation
dentists_df = pd.DataFrame(deduplicated_dentists)
dentists_df['size'] = dentists_df['reviews'].apply(ratings_to_size)

# Display a few rows to verify
display(property_data.head())
display(dentists_df.head())
# Out:
#     longitude   latitude
# 0  172.682428 -43.569101
# 1  174.766058 -36.850536
# 2  174.766289 -36.848008
# 3  174.770643 -36.847417
# 4  174.753391 -36.860142
#                       place_id                    name        lat         lon  \
# 0  ChIJn2iTgIGqEm0R3tcUFgH1VDY             Mint Dental -37.191588  174.903652
# 1  ChIJZ1N2dWKqEm0RZV_x3mljNxU  Pukekohe Orthodontists -37.074346  174.922603
# 2  ChIJZ6Hm7Aqtcm0R7hsARw807lE         Papakura Dental -37.063744  174.942566
# 3  ChIJiQWVRdSscm0RgB5b7NnhmNM         The Denture Man -37.064653  174.943538
# 4  ChIJz13Dp9Wscm0Ru9TUvS4DslY   Dental World Papakura -37.063301  174.943527
#
#    reviews      size
# 0       39  2.624500
# 1        3  2.173205
# 2        7  2.264575
# 3        9  2.300000
# 4        7  2.264575

# %%
sample_size = int(len(property_data) * sample_percentage)  # Sample % of the rows

# Define property_for_huff which can be set to either the full data or a sample
def set_property_for_huff(full_data, sample_size=None):
    if sample_size:
        return full_data.sample(n=sample_size, random_state=42)  # Create a random sample
    return full_data  # Use the full dataset if no sample_size is provided

# Example usage
# For full data (use this in the main run)
property_for_huff = set_property_for_huff(property_data, sample_size)

# For testing with a random sample of, say, 1000 rows (use this for faster testing)
# property_for_huff = set_property_for_huff(property_data, sample_size=1000)

# Display the first few rows to verify
display(property_for_huff.head())
# Out:
#           longitude   latitude
# 1440305  173.937789 -41.507538
# 1921502  174.362696 -35.751926
# 2140332  175.009620 -37.237635
# 246221   172.598556 -43.497314
# 1196567  175.629666 -40.346956

# %%
import numpy as np

# Function to calculate distance between two points (Haversine formula)
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371  # Radius of Earth in kilometers
    return c * r  # Distance in kilometers

# Test the function

# %%
from tqdm import tqdm


# Convert property data and dentists data to NumPy arrays for fast operations
property_lats = property_for_huff['latitude'].values
property_lons = property_for_huff['longitude'].values

dentist_lats = dentists_df['lat'].values
dentist_lons = dentists_df['lon'].values
dentist_sizes = dentists_df['size'].values

# Initialize an array to store the total estimated revenue for each dentist
revenue_per_practice = np.zeros(len(dentist_lats))

# Vectorized calculation of distances from all properties to all dentists
for i in tqdm(range(len(property_lats)), desc="Processing Properties", total=len(property_lats)):
    # Compute distances from the current property to all dentists at once
    distances = haversine(property_lats[i], property_lons[i], dentist_lats, dentist_lons)

    # Compute size over distance^beta (for all dentists)
    size_over_distance = dentist_sizes / distances**beta
    
    # Compute the probabilities (for all dentists)
    probabilities = size_over_distance / size_over_distance.sum()

    # Distribute customer value to each dental practice based on the probabilities
    revenue_per_practice += probabilities * customer_value
# Out:
# Processing Properties: 100%|██████████| 2360762/2360762 [01:17<00:00, 30400.84it/s]

# %%
property_lats.shape
# Out:
# (2360762,)

# %%
# Scale the revenue by the sampling ratio (to account for partial data)
revenue_per_practice /= sample_percentage

# Add the revenue estimate to the dentists DataFrame
dentists_df['estimated_revenue'] = revenue_per_practice

# %%
from IPython.display import display
pd.set_option('display.max_rows', None)

# Sort the DataFrame by 'estimated_revenue' first (while it's still numeric)
sorted_dentists_df = dentists_df.sort_values(by='estimated_revenue', ascending=False)

# Truncate the name at 30 characters and create a new column for the formatted revenue
sorted_dentists_df['name_truncated'] = sorted_dentists_df['name'].apply(lambda x: x[:30])
sorted_dentists_df['formatted_revenue'] = sorted_dentists_df['estimated_revenue'].map(lambda x: f"${x:,.0f}")

# Select relevant columns for display
formatted_output = sorted_dentists_df[['name_truncated', 'formatted_revenue']]

# Display the formatted DataFrame
display(formatted_output)
# Out:
#                      name_truncated formatted_revenue
# 161  Smile Dental - Queen Street -         $3,158,736
# 35         Maxcare Dental - Otahuhu        $2,757,974
# 72           Donna Lim Orthodontics        $2,445,740
# 69   Stoddard Dental Square ! Emerg        $2,295,505
# 134     Pt Chevalier Family Dentist        $2,252,393
# 12           Smile Dental - Manukau        $2,233,162
# 142  Dental Artistry - Auckland Den        $2,204,358
# 154  Accent Dentists - Cosmetic Den        $2,193,310
# 183                 Northmed Dental        $2,188,944
# 45     Blockhouse Bay Dental Centre        $2,175,671
# 107                   Alpers Dental        $2,155,567
# 41                  DentalCare West        $2,086,010
# 156  The Fono City Healthcare Centr        $2,055,933
# 173             Affordable Dentists        $2,053,851
# 129                  CM Dental Ltd.        $2,032,490
# 55   Smile Dental - Onehunga Dentis        $2,023,920
# 139                  Grafton Dental        $2,012,015
# 199  Auckland Family Dental: Milfor        $1,995,498
# 140    Symonds Street Dental Centre        $1,994,704
# 49   Quality Care Dental | Dentist         $1,982,227
# 137               Eden Orthodontics        $1,973,642
# 187  Shakespeare Orthodontics Takap        $1,966,220
# 109  Shakespeare Orthodontics Epsom        $1,954,678
# 164  Lumino City Dental at Quay Par        $1,952,788
# 149                    Hello Dental        $1,944,985
# 78     Caring 4 Smiles Dental Group        $1,925,536
# 47            Auckland Orthodontics        $1,921,328
# 44           West Auckland Dentists        $1,889,739
# 52            Dental Today Onehunga        $1,877,347
# 217           Bayside Dental Centre        $1,874,848
# 87   Primecare Dental Highland Park        $1,861,833
# 5                  Nova Dental Care        $1,852,018
# 200               Sunnynook Dentist        $1,851,154
# 101               All Smiles Dental        $1,847,332
# 57           Ti Rakau Dental Centre        $1,841,484
# 106                  Epsom Dentists        $1,824,983
# 130              White Cross Dental        $1,820,921
# 195  Mint Dental Hygiene / Nova Edg        $1,820,135
# 150                Dr Dave Richards        $1,813,999
# 13             Guardian Dental Care        $1,811,778
# 6             Clendon Dental Centre        $1,785,120
# 9            Mahu Dental - Manurewa        $1,785,005
# 65   Auckland Family Dental: New Ly        $1,773,541
# 64      White Cross Dental New Lynn        $1,772,781
# 63              Kelston Dental Care        $1,770,367
# 80            Penrose Dental Clinic        $1,768,462
# 148     The Tooth Company Eastridge        $1,761,247
# 127   Marina Dentists Half Moon Bay        $1,753,384
# 166     The Tooth Company Britomart        $1,751,087
# 97        Mount Albert Orthodontics        $1,746,947
# 159                Re Dental Clinic        $1,741,879
# 0                       Mint Dental        $1,738,140
# 14             Southern Care Dental        $1,737,033
# 205                     Bays Dental        $1,725,245
# 70           Dominion Dental Centre        $1,724,805
# 220              Clean Teeth Dental        $1,724,153
# 105               Neo Dental Studio        $1,721,631
# 94   The Fono Henderson Healthcare         $1,716,724
# 33   Primecare Dental Mangere Bridg        $1,712,661
# 162  Auckland Central | Lumino The         $1,708,791
# 60         Family Dentist Pakuranga        $1,707,971
# 10   The Fono Manurewa Healthcare C        $1,701,814
# 102  Lumino The Dentists Mount Eden        $1,700,881
# 174       Mokoia Road Dental Centre        $1,699,733
# 90                      A+ Dentists        $1,698,288
# 37            Mahu Dental - Otahuhu        $1,698,215
# 82    Affordable Dentists Ellerslie        $1,696,102
# 138  Ponsonby Dentist | Lumino The         $1,695,294
# 128                Macleans Dentist        $1,695,108
# 204                The Tooth Doctor        $1,692,298
# 179        Hobsonville Point Dental        $1,689,959
# 196            Auckland Dental Care        $1,689,892
# 7                     Loudon Dental        $1,677,806
# 176         Northcote Dental Centre        $1,672,504
# 56           My Dentist - Pakuranga        $1,668,560
# 180               Ocean View Dental        $1,668,351
# 144               Milk Orthodontics        $1,664,820
# 43   Lumino The Dentists | New Lynn        $1,662,931
# 212                 Greville Dental        $1,650,705
# 11   Advanced Dental Care Manurewa         $1,648,638
# 81                 Greenlane Dental        $1,646,993
# 24        Papatoetoe Family Dentist        $1,643,856
# 62                 Golflands Dental        $1,642,404
# 145          Janice Sommerville Ltd        $1,641,683
# 178                   Fraser Dental        $1,635,253
# 104  Lumino Mount Eden Village | Lu        $1,634,743
# 100            Flash Dental Mt Eden        $1,629,406
# 112                 Cosmetic Dental        $1,628,486
# 67             Totara Orthodontists        $1,624,956
# 219  Dr Kimberley Timmins Specialis        $1,624,551
# 157        Ponsonby Dental Boutique        $1,624,163
# 22                  Guardian Dental        $1,618,973
# 18             Prisca Dental Centre        $1,612,788
# 53          Trafalgar Family Dental        $1,608,955
# 66                   Quality Dental        $1,608,954
# 208                   JJ Dentalcare        $1,607,601
# 29              Botany South Dental        $1,607,520
# 211                 Northmed Dental        $1,606,500
# 84             Dental World Panmure        $1,604,909
# 184   The Tooth Company Smales Farm        $1,603,992
# 170                   Massey Smiles        $1,603,266
# 8            Manurewa Dental Centre        $1,592,785
# 110                 Dental Cosmetic        $1,590,240
# 158                  Ponsonby Teeth        $1,586,903
# 28              East Tamaki Dentist        $1,585,657
# 36            South Auckland Dental        $1,582,868
# 71                  Thompson Dental        $1,582,249
# 201                     Star Dental        $1,576,729
# 120                 Lunn Dental Spa        $1,575,518
# 34              OTAHUHU DENTAL CARE        $1,575,309
# 182              The Dental Experts        $1,562,511
# 98      White Cross Dental St Lukes        $1,559,187
# 32          Titirangi Dental Centre        $1,548,760
# 165                 Downtown Dental        $1,548,340
# 96           Dental on Mount Albert        $1,547,218
# 27                 Flat Bush Dental        $1,543,962
# 76           Balmoral Dental Centre        $1,540,428
# 209               DBS Dental Studio        $1,539,623
# 23         Papatoetoe Dental Centre        $1,537,229
# 153  Ponsonby Accident & Emergency         $1,536,158
# 123             Urban Dental Studio        $1,532,479
# 206              Sunset Dental Care        $1,530,097
# 155      Freemans Bay Dental Centre        $1,527,617
# 215           Albany Village Dental        $1,527,186
# 79   Gentle Dentists Ellerslie | Lu        $1,526,923
# 118  Max + Beresford Orthodontists         $1,524,323
# 191  Takapuna Como Street | Lumino         $1,520,389
# 74   Lumino Three Kings | Lumino Th        $1,517,654
# 198                Milford Dentists        $1,516,996
# 135      Pt Chevalier Dental Centre        $1,515,419
# 136              Eden Dental Centre        $1,513,084
# 175          Dentists on Birkenhead        $1,511,399
# 172  Viva Dental Birkenhead | Lumin        $1,503,116
# 146               Aevitas Dentistry        $1,502,704
# 203  Wairau Park Dental Centre | Lu        $1,500,630
# 171                Devonport Dental        $1,495,388
# 2             Vanessa Wright Dental        $1,490,731
# 16       Airport Oaks Dental Centre        $1,488,259
# 17            Mangere Dental Centre        $1,487,312
# 188               Takapuna Dentists        $1,486,843
# 26   Ormiston Dental Centre Flat Bu        $1,486,431
# 143                  Inspire Dental        $1,481,857
# 131  Henderson Dental Practice | Lu        $1,481,395
# 168            Massey Dental Centre        $1,478,522
# 73        Three Kings Dental Centre        $1,477,959
# 3                   The Denture Man        $1,475,807
# 126        Glen Innes Dental Centre        $1,472,854
# 25   Botany Orthodontist - Coreen L        $1,471,302
# 51           Onehunga Dental Centre        $1,461,987
# 152                 Dental Boutique        $1,460,936
# 121  Kidz-Teeth Meadowbank | Lumino        $1,459,558
# 193      Takapuna Orthodontic Group        $1,457,673
# 113  Lumino The Dentists: Remuera D        $1,456,726
# 77          Auckland Denture Clinic        $1,452,994
# 4             Dental World Papakura        $1,449,864
# 39   Botany Dental Practice | Lumin        $1,449,210
# 19           Papatoetoe Dental Care        $1,447,860
# 61              The Dental Practice        $1,446,729
# 124          Dental Wellness Centre        $1,436,543
# 88          The Endodontic Practice        $1,436,431
# 21        John Hodgson Orthodontist        $1,434,773
# 163           Auckland City Dentist        $1,426,917
# 42   Frank Matheson's Dental Surger        $1,425,856
# 108                   Belich Dental        $1,424,457
# 181  Glenfield Dental North Shore |        $1,424,219
# 114   Catherine Porter Orthodontist        $1,412,949
# 132           Peninsula Dental Care        $1,409,735
# 122        Meadowbank Dental Centre        $1,406,392
# 125              Glen Innes Dentist        $1,406,267
# 91             Dental Planet Howick        $1,400,115
# 89      Highland Park Dental Centre        $1,397,857
# 115  Pearl Dental Centre Remuera |         $1,393,909
# 218    The Dental Centre Browns Bay        $1,392,886
# 169          Westgate Dental Centre        $1,392,592
# 31    Titirangi Village Dental Care        $1,391,762
# 20            Hunters Corner Dental        $1,389,715
# 167  Lumino St Heliers | Lumino The        $1,387,219
# 50          The Dentists - Auckland        $1,383,179
# 30                 VS Dental Studio        $1,376,526
# 202            Kim's Dental Surgery        $1,375,134
# 116             Dental On Greenlane        $1,367,132
# 54                Onehunga Dentists        $1,363,234
# 95                  Te Atatu Dental        $1,359,695
# 59             Dentalcare Pakuranga        $1,356,911
# 68         HillPark Dental Avondale        $1,356,653
# 85   Fraser Smith Lowe Dentists Lim        $1,354,091
# 75        Sandringham Dental Centre        $1,348,044
# 151         St Heliers Dental Group        $1,346,044
# 103  Balmoral Intermediate Children        $1,344,782
# 83            Panmure Dental Centre        $1,343,048
# 117                          .Ortho        $1,339,839
# 141       Casley, Wong & Tam Dental        $1,336,914
# 160                   Dental Direct        $1,334,464
# 133                    Meola Dental        $1,333,902
# 177               Dental Studio 114        $1,329,875
# 210  Lumino Rosedale | Lumino The D        $1,329,453
# 207                     Tusk Dental        $1,324,545
# 186              My Dental Implants        $1,324,212
# 1            Pukekohe Orthodontists        $1,323,660
# 48     Mt Roskill South Dental Care        $1,308,392
# 192                  JJY Dental Ltd        $1,301,772
# 92    Derek Barwood Orthodontic Ltd        $1,287,501
# 99                   Dental Surgeon        $1,286,473
# 58         Pakuranga Dental Surgery        $1,281,666
# 147                  Chris Waalkens        $1,281,417
# 197            Huapai Dental Centre        $1,269,036
# 216  Northcross Intermediate dental        $1,266,701
# 86   Wakaaranga School Dental Clini        $1,265,792
# 213           Albany Dental Surgery        $1,244,583
# 93   Shakespeare Orthodontics Howic        $1,238,354
# 15            Manukau Dental Clinic        $1,225,246
# 40                      Dr Jacy Lin        $1,197,348
# 111                       Smileplan        $1,180,377
# 119  Auckland City Orthodontics Rem        $1,174,377
# 46                   Dr John Coburn        $1,170,773
# 38   Auckland City Orthodontics Hig        $1,164,304
# 194        North Shore Periodontics        $1,160,253
# 190  Bunyan Dr TR Specialist Orthod        $1,153,296
# 185                Warren Jenks Ltd        $1,151,927
# 189                         goSmart        $1,097,982
# 214            White Crystal Dental        $1,081,336

# %%
display(dentists_df)
# Out:
#                       place_id                    name        lat         lon  \
# 0  ChIJn2iTgIGqEm0R3tcUFgH1VDY             Mint Dental -37.191588  174.903652
# 1  ChIJZ1N2dWKqEm0RZV_x3mljNxU  Pukekohe Orthodontists -37.074346  174.922603
# 2  ChIJPx17MdWscm0RaYxnKNKfAcg   Vanessa Wright Dental -37.062908  174.940487
# 3  ChIJiQWVRdSscm0RgB5b7NnhmNM         The Denture Man -37.064653  174.943538
# 4  ChIJz13Dp9Wscm0Ru9TUvS4DslY   Dental World Papakura -37.063301  174.943527
#
#    reviews      size  estimated_revenue
# 0       39  2.624500       1.738140e+06
# 1        3  2.173205       1.323660e+06
# 2       11  2.331662       1.490731e+06
# 3        9  2.300000       1.475807e+06
# 4        7  2.264575       1.449864e+06

# %%
property_data.shape
# Out:
# (2360762, 2)

# %%
1+1
